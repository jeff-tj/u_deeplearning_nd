# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [02:28, 212KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
print(int_words[:30])
# Out:
# [5238, 3081, 11, 5, 194, 1, 3135, 45, 58, 155, 127, 741, 476, 10595, 133, 0, 27528, 1, 0, 102, 854, 2, 0, 15132, 63537, 1, 0, 150, 854, 3582]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import collections

def subsample(wordlist, threshold):
    """
    Take a word list and threshold and subsample on Mikolov Prob
    """
    subsample_counter = collections.Counter(wordlist)
    prob_dict = {}
    total_words = len(wordlist)
    
    for (word_int, word_n) in subsample_counter.most_common():
        prob_dict[word_int] = 1 - np.sqrt(threshold / (word_n / total_words))
    
    subsample_list = []
    for word_int in wordlist:
        if np.random.random() < (1 - prob_dict[word_int]):
            subsample_list.append(word_int)
    
    return subsample_list

train_words = subsample(int_words, 1e-5)# The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = int(np.ceil(window_size * np.random.random()))
    rng_l = max(0, idx - r)
    
    word_list = set(words[rng_l:idx] + words[idx + 1:idx + r + 1])
    
    return list(word_list)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="outputs")

# Work back and figure out how we've set dimensions here!

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  300 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1)) 
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=1))
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 21.7470 0.1179 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 21.5606 0.1126 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 21.1979 0.1123 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 21.1454 0.1128 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 20.9530 0.1126 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 20.8239 0.1131 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 20.7051 0.1127 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 20.5688 0.1151 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 20.4262 0.1173 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 20.2820 0.1189 sec/batch
# Nearest to new: orgel, archaeological, tout, unimpeded, segmented, blasphemous, marianas, pino,
# Nearest to from: gdf, chlorine, pericardium, scalar, beltline, zionists, baffling, boastful,
# Nearest to but: cobol, tapaj, gu, immigrant, kut, lows, madsen, fjords,
# Nearest to war: pattie, trois, undisclosed, conventions, ischemic, charlatans, huike, monopolized,
# Nearest to its: virtues, willoughby, flanked, knots, difference, farian, felines, pugwash,
# Nearest to on: olcott, noodle, binet, cherokees, mayhew, aeroflot, john, lorde,
# Nearest to years: sharqi, ordinals, nitrogen, huevos, hate, gershom, tsk, subterranean,
# Nearest to one: madox, aldiss, cosmopolitanism, ngc, cmf, mishima, hid, merlini,
# Nearest to stage: latter, gign, beef, hairdresser, ssi, michio, nextstep, storming,
# Nearest to shows: musculus, talvela, nchen, virology, maryland, annexes, lucca, jumo,
# Nearest to existence: denard, ansel, wert, schmidt, eternal, mok, roundel, acoustic,
# Nearest to mainly: ssr, bech, touches, hydrolysed, lair, hitherto, countering, enslavement,
# Nearest to channel: salman, marotta, averted, flavonoids, lander, oersted, giving, gop,
# Nearest to mathematics: perse, harwich, thessalonica, motivic, maxfield, copernican, lindbergh, dimers,
# Nearest to running: restorer, chalker, clockwise, grosz, bingo, tsunamis, hunyadi, ammonia,
# Nearest to operations: honest, akad, bladder, sdp, seaton, nintoku, ramanuja, skies,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 20.1781 0.1217 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 20.0911 0.1216 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 19.9006 0.1232 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 19.8426 0.1238 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 19.6126 0.1245 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 19.5155 0.1245 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 19.4436 0.1261 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 19.2863 0.1258 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 19.2741 0.1258 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 19.0357 0.1257 sec/batch
# Nearest to new: archaeological, orgel, tout, unimpeded, segmented, blasphemous, oppressed, marianas,
# Nearest to from: scalar, gdf, baffling, pericardium, chlorine, zionists, blunder, beltline,
# Nearest to but: cobol, tapaj, fjords, abyssinia, gu, kut, immigrant, lows,
# Nearest to war: pattie, trois, undisclosed, conventions, charlatans, ischemic, huike, argus,
# Nearest to its: virtues, flanked, willoughby, knots, felines, farian, difference, pugwash,
# Nearest to on: olcott, binet, cherokees, noodle, mayhew, aeroflot, john, lorde,
# Nearest to years: ordinals, sharqi, nitrogen, huevos, gershom, arrhenius, hate, rerio,
# Nearest to one: cosmopolitanism, aldiss, cmf, madox, ngc, hid, merlini, mishima,
# Nearest to stage: latter, gign, hairdresser, storming, beef, michio, nextstep, foursome,
# Nearest to shows: musculus, talvela, nchen, virology, annexes, maryland, lucca, fractal,
# Nearest to existence: denard, wert, ansel, mok, schmidt, roundel, lumber, eternal,
# Nearest to mainly: ssr, countering, touches, hydrolysed, bech, hitherto, lair, enslavement,
# Nearest to channel: salman, marotta, averted, flavonoids, lander, investigators, gop, giving,
# Nearest to mathematics: thessalonica, motivic, maxfield, harwich, perse, copernican, cannonball, doom,
# Nearest to running: restorer, chalker, clockwise, grosz, bingo, tsunamis, notebook, hunyadi,
# Nearest to operations: honest, akad, bladder, nintoku, seaton, sdp, skies, ramanuja,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 18.9270 0.1280 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 18.8619 0.1278 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 18.7890 0.1277 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 18.6183 0.1275 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 18.4633 0.1276 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 18.4537 0.1277 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 18.3107 0.1277 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 18.2798 0.1278 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 18.0942 0.1282 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 17.9988 0.1283 sec/batch
# Nearest to new: archaeological, orgel, unimpeded, segmented, tout, voegelin, oppressed, marianas,
# Nearest to from: gdf, baffling, chlorine, scalar, pericardium, zionists, beltline, rta,
# Nearest to but: cobol, tapaj, puckle, fjords, abyssinia, gu, kut, madsen,
# Nearest to war: pattie, trois, undisclosed, ischemic, huike, veritas, conventions, argus,
# Nearest to its: virtues, flanked, willoughby, knots, farian, felines, difference, bluff,
# Nearest to on: olcott, binet, noodle, cherokees, john, vidarbha, pygmy, lorde,
# Nearest to years: ordinals, nitrogen, sharqi, hate, arrhenius, huevos, trolley, insistence,
# Nearest to one: cosmopolitanism, cmf, aldiss, ngc, merlini, hid, madox, belgica,
# Nearest to stage: latter, gign, foursome, hairdresser, beef, storming, abkhazian, michio,
# Nearest to shows: musculus, maryland, talvela, annexes, nchen, virology, lucca, fractal,
# Nearest to existence: denard, wert, ansel, mok, roundel, schmidt, lumber, acoustic,
# Nearest to mainly: ssr, countering, bech, hydrolysed, touches, babylon, lair, hitherto,
# Nearest to channel: salman, marotta, flavonoids, lander, averted, investigators, gop, nevers,
# Nearest to mathematics: maxfield, harwich, thessalonica, perse, motivic, copernican, cannonball, doom,
# Nearest to running: restorer, chalker, clockwise, grosz, notebook, bingo, hunyadi, interpolant,
# Nearest to operations: honest, nintoku, seaton, bladder, sdp, akad, ramanuja, skies,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 17.8931 0.1298 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 17.8311 0.1295 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 17.6908 0.1305 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 17.6635 0.1303 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 17.6009 0.1314 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 17.4954 0.1299 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 17.3616 0.1292 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 17.3017 0.1288 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 17.1420 0.1295 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 17.0526 0.1298 sec/batch
# Nearest to new: archaeological, unimpeded, orgel, tout, segmented, oppressed, voegelin, wollaston,
# Nearest to from: gdf, chlorine, baffling, scalar, beltline, rta, desert, deposits,
# Nearest to but: fjords, cobol, abyssinia, puckle, tapaj, madsen, samoans, immigrant,
# Nearest to war: pattie, trois, undisclosed, veritas, huike, argus, charlatans, corr,
# Nearest to its: virtues, flanked, willoughby, knots, bluff, farian, foundry, difference,
# Nearest to on: noodle, binet, olcott, john, vidarbha, cherokees, pygmy, polysaccharides,
# Nearest to years: ordinals, nitrogen, sharqi, arrhenius, huevos, hate, touma, valuation,
# Nearest to one: cmf, ngc, cosmopolitanism, hid, paullus, merlini, aldiss, mishima,
# Nearest to stage: latter, hairdresser, gign, beef, cumulus, storming, abkhazian, foursome,
# Nearest to shows: musculus, annexes, talvela, maryland, lucca, virology, nchen, chorale,
# Nearest to existence: denard, ansel, wert, mok, roundel, kern, lumber, electorates,
# Nearest to mainly: ssr, bech, hitherto, hydrolysed, touches, babylon, lair, countering,
# Nearest to channel: salman, marotta, flavonoids, lander, investigators, nevers, averted, parochial,
# Nearest to mathematics: maxfield, harwich, thessalonica, motivic, copernican, perse, cannonball, doom,
# Nearest to running: restorer, chalker, clockwise, grosz, tsunamis, bingo, stupor, notebook,
# Nearest to operations: honest, seaton, nintoku, tofu, bladder, sdp, fgm, akad,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 17.0617 0.1301 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 16.8595 0.1292 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 16.7327 0.1307 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 16.6577 0.1301 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 16.6558 0.1293 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 16.5875 0.1292 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 16.2989 0.0949 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 16.1930 0.1298 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 16.1511 0.1290 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 15.9780 0.1283 sec/batch
# Nearest to new: archaeological, unimpeded, orgel, tout, oppressed, have, segmented, certify,
# Nearest to from: gdf, baffling, quakers, chlorine, desert, scalar, questionable, pirin,
# Nearest to but: gu, tapaj, fjords, cobol, madsen, samoans, immigrant, isuzu,
# Nearest to war: pattie, trois, undisclosed, englehart, veritas, ischemic, monopolized, america,
# Nearest to its: virtues, willoughby, flanked, farian, bluff, difference, knots, foundry,
# Nearest to on: binet, isolation, noodle, olcott, pygmy, vidarbha, john, decadent,
# Nearest to years: ordinals, confirmation, sharqi, arrhenius, nitrogen, valuation, tsk, huevos,
# Nearest to one: cosmopolitanism, cmf, aldiss, ngc, merlini, brash, replicants, hid,
# Nearest to stage: latter, gign, hairdresser, foursome, beef, michio, abkhazian, storming,
# Nearest to shows: musculus, annexes, maryland, talvela, virology, nchen, lucca, chorale,
# Nearest to existence: denard, ansel, wert, kern, mok, roundel, diam, electorates,
# Nearest to mainly: ssr, bech, hydrolysed, hitherto, lair, touches, babylon, countering,
# Nearest to channel: salman, marotta, flavonoids, lander, nevers, investigators, parochial, averted,
# Nearest to mathematics: thessalonica, maxfield, harwich, motivic, cannonball, perse, copernican, ua,
# Nearest to running: restorer, chalker, clockwise, grosz, bingo, tsunamis, stupor, notebook,
# Nearest to operations: honest, seaton, nintoku, fgm, bladder, sdp, tofu, ramanuja,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 15.9445 0.1299 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 15.8716 0.1287 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 15.7466 0.1296 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 15.6248 0.1293 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 15.4971 0.1292 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 15.5566 0.1303 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 15.2387 0.1307 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 15.2397 0.1307 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 15.1549 0.1315 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 15.1428 0.1314 sec/batch
# Nearest to new: archaeological, have, tout, oppressed, certify, segmented, of, orgel,
# Nearest to from: baffling, gdf, of, desert, chlorine, pericardium, pirin, quakers,
# Nearest to but: tapaj, gu, fjords, isuzu, graham, bombs, madsen, herstal,
# Nearest to war: pattie, trois, undisclosed, america, englehart, charlatans, ischemic, veritas,
# Nearest to its: virtues, willoughby, bluff, farian, flanked, knots, curricula, artisan,
# Nearest to on: and, binet, noodle, isolation, decadent, quds, pygmy, john,
# Nearest to years: sharqi, ordinals, brice, valuation, tsk, huevos, ulfilas, two,
# Nearest to one: the, in, two, zero, to, ngc, cosmopolitanism, aldiss,
# Nearest to stage: latter, gign, hairdresser, beef, foursome, michio, whitworth, abkhazian,
# Nearest to shows: musculus, talvela, annexes, maryland, lucca, chorale, virology, tsu,
# Nearest to existence: denard, ansel, wert, kern, diam, electorates, deo, roundel,
# Nearest to mainly: ssr, hitherto, bech, lair, hydrolysed, babylon, countering, touches,
# Nearest to channel: salman, marotta, nevers, flavonoids, quixote, oersted, lander, parochial,
# Nearest to mathematics: thessalonica, maxfield, harwich, motivic, cannonball, perse, copernican, doom,
# Nearest to running: restorer, chalker, clockwise, grosz, tsunamis, bingo, unicode, stupor,
# Nearest to operations: seaton, nintoku, honest, ramanuja, fgm, sdp, tofu, counterterrorism,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 15.1431 0.1326 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 14.9371 0.1308 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 14.8886 0.1309 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 14.7890 0.1312 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 14.8493 0.1295 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 14.7065 0.1298 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 14.3914 0.1302 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 14.4718 0.1304 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 14.4158 0.1301 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 14.3812 0.1299 sec/batch
# Nearest to new: have, archaeological, oppressed, filo, segmented, unimpeded, tout, certify,
# Nearest to from: of, the, a, to, in, and, as, for,
# Nearest to but: is, of, and, graham, the, to, for, a,
# Nearest to war: trois, pattie, undisclosed, america, englehart, charlatans, veritas, monopolized,
# Nearest to its: virtues, willoughby, farian, flanked, delgada, bluff, jets, knots,
# Nearest to on: of, and, a, in, the, is, to, that,
# Nearest to years: two, brice, tsk, ordinals, made, valuation, sharqi, ulfilas,
# Nearest to one: the, of, in, and, zero, to, a, nine,
# Nearest to stage: latter, hairdresser, gign, beef, collection, happening, whitworth, abkhazian,
# Nearest to shows: musculus, talvela, annexes, darker, tsu, maryland, nchen, chorale,
# Nearest to existence: denard, ansel, electorates, diam, flush, wert, deo, kern,
# Nearest to mainly: ssr, lair, hitherto, babylon, bech, countering, hydrolysed, jains,
# Nearest to channel: salman, marotta, flavonoids, nevers, quixote, oersted, lander, investigators,
# Nearest to mathematics: thessalonica, motivic, maxfield, harwich, cannonball, perse, copernican, doom,
# Nearest to running: restorer, chalker, clockwise, tsunamis, stupor, bingo, gerhardt, grosz,
# Nearest to operations: seaton, nintoku, fgm, honest, ramanuja, tofu, sdp, counterterrorism,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 14.4137 0.1307 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 14.2023 0.1291 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 13.9170 0.1295 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 14.1102 0.1291 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 14.0838 0.1292 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 13.8043 0.1296 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 13.8503 0.1295 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 13.8667 0.1306 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 13.5236 0.1310 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 13.6160 0.1311 sec/batch
# Nearest to new: of, from, one, a, have, the, but, by,
# Nearest to from: and, of, a, the, to, for, in, is,
# Nearest to but: that, the, of, to, a, for, and, in,
# Nearest to war: pattie, trois, america, undisclosed, englehart, huike, charlatans, nutshell,
# Nearest to its: in, of, at, and, the, with, that, to,
# Nearest to on: in, of, to, the, and, a, is, that,
# Nearest to years: two, one, zero, made, was, tsk, three, four,
# Nearest to one: zero, two, three, nine, five, seven, four, in,
# Nearest to stage: latter, hairdresser, gign, beef, collection, abkhazian, lacaille, whitworth,
# Nearest to shows: musculus, talvela, annexes, clans, chorale, virology, surgical, darker,
# Nearest to existence: denard, electorates, diam, wert, buick, flush, ansel, corsa,
# Nearest to mainly: ssr, lair, bech, official, countering, babylon, punch, pogson,
# Nearest to channel: salman, marotta, nevers, quixote, oersted, flavonoids, lander, bragging,
# Nearest to mathematics: harwich, thessalonica, maxfield, perse, motivic, copernican, cannonball, communitarian,
# Nearest to running: restorer, chalker, clockwise, tsunamis, unicode, gerhardt, bingo, stupor,
# Nearest to operations: fgm, seaton, nintoku, honest, ramanuja, hauling, tofu, powerbook,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 13.4297 0.1328 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 13.6373 0.1309 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 13.4498 0.1300 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 13.4078 0.1305 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 13.3268 0.1302 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 13.0430 0.1300 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 13.3251 0.1296 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 13.0953 0.1296 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 12.9261 0.1305 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 12.9292 0.1308 sec/batch
# Nearest to new: the, a, an, in, but, is, or, all,
# Nearest to from: the, a, and, as, that, of, in, to,
# Nearest to but: to, the, a, of, that, and, it, in,
# Nearest to war: pattie, has, america, englehart, zero, was, which, trois,
# Nearest to its: the, and, of, was, in, a, with, from,
# Nearest to on: the, as, and, a, of, in, it, this,
# Nearest to years: two, zero, with, s, five, three, four, to,
# Nearest to one: nine, two, five, seven, four, eight, zero, three,
# Nearest to stage: latter, hairdresser, collection, gign, seceding, whitworth, beef, manning,
# Nearest to shows: musculus, annexes, talvela, darker, clans, chorale, virology, tsu,
# Nearest to existence: denard, electorates, diam, wert, flush, ansel, buick, corsa,
# Nearest to mainly: ssr, official, bech, lair, babylon, late, punch, hitherto,
# Nearest to channel: salman, marotta, nevers, oersted, quixote, flavonoids, lander, embryology,
# Nearest to mathematics: harwich, thessalonica, motivic, perse, maxfield, communitarian, doom, copernican,
# Nearest to running: restorer, chalker, clockwise, tsunamis, bingo, application, unicode, stupor,
# Nearest to operations: fgm, seaton, nintoku, honest, counterterrorism, ramanuja, sdp, tofu,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 12.9723 0.1311 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 12.9133 0.1297 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 12.8085 0.0600 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 12.6538 0.1298 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 12.6091 0.1294 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 12.5558 0.1291 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 12.4934 0.1286 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 12.4007 0.1294 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 12.2542 0.1296 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 12.1132 0.1294 sec/batch
# Nearest to new: a, the, four, in, on, of, and, which,
# Nearest to from: the, in, of, as, a, and, to, this,
# Nearest to but: as, a, to, the, of, this, that, and,
# Nearest to war: he, in, two, s, who, and, one, four,
# Nearest to its: the, in, a, and, has, from, this, of,
# Nearest to on: the, of, as, in, a, to, this, and,
# Nearest to years: five, zero, two, one, the, three, for, four,
# Nearest to one: nine, seven, six, five, eight, two, four, three,
# Nearest to stage: latter, collection, gign, made, realized, seceding, hairdresser, beef,
# Nearest to shows: musculus, clans, annexes, surgical, until, tsu, internacia, darker,
# Nearest to existence: denard, electorates, ansel, buick, boggy, wert, muscular, flush,
# Nearest to mainly: official, ssr, bech, lair, angina, babylon, late, punch,
# Nearest to channel: salman, marotta, nevers, quixote, oersted, flavonoids, embryology, jean,
# Nearest to mathematics: use, harwich, thessalonica, however, role, motivic, communitarian, maxfield,
# Nearest to running: restorer, chalker, application, tsunamis, clockwise, bingo, react, impatience,
# Nearest to operations: fgm, counterterrorism, seaton, honest, low, sdp, ramanuja, commodity,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 12.1110 0.1305 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 12.1336 0.1300 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 11.9947 0.1309 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 11.7025 0.1314 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 11.8230 0.1315 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 11.8778 0.1314 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 11.9647 0.1310 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 11.7782 0.1309 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 11.6189 0.1308 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 11.5650 0.1313 sec/batch
# Nearest to new: in, of, and, was, the, a, by, first,
# Nearest to from: the, in, a, of, and, to, this, is,
# Nearest to but: the, that, of, be, to, it, a, and,
# Nearest to war: two, was, he, his, s, eight, one, six,
# Nearest to its: the, of, to, in, a, and, for, this,
# Nearest to on: the, of, in, to, at, by, be, its,
# Nearest to years: zero, one, six, five, three, two, four, eight,
# Nearest to one: four, five, six, nine, zero, two, eight, three,
# Nearest to stage: made, latter, collection, realized, eventually, whitworth, beef, hairdresser,
# Nearest to shows: musculus, links, clans, until, annexes, darker, ultramagnetic, designers,
# Nearest to existence: denard, electorates, eternal, boggy, whereas, diam, herb, magellan,
# Nearest to mainly: ssr, official, late, during, angina, there, punch, lair,
# Nearest to channel: salman, marotta, nevers, flavonoids, oersted, quixote, jean, embryology,
# Nearest to mathematics: harwich, use, thessalonica, perse, role, themselves, however, maxfield,
# Nearest to running: restorer, application, chalker, clockwise, tsunamis, variable, impatience, bead,
# Nearest to operations: low, sdp, seaton, commodity, hauling, counterterrorism, fgm, continual,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 11.6025 0.1311 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 11.6967 0.1295 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 11.2340 0.1298 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 11.2840 0.1301 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 11.3456 0.1308 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 11.2178 0.1297 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 11.2550 0.1298 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 11.2518 0.1296 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 10.8359 0.1295 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 11.0850 0.1296 sec/batch
# Nearest to new: the, in, as, were, was, for, of, by,
# Nearest to from: the, as, of, it, for, that, and, is,
# Nearest to but: of, the, as, to, it, that, not, and,
# Nearest to war: was, were, in, had, after, united, one, to,
# Nearest to its: in, the, and, a, of, for, to, by,
# Nearest to on: to, the, and, of, many, in, a, as,
# Nearest to years: zero, two, three, five, four, one, six, nine,
# Nearest to one: nine, eight, six, seven, three, five, two, zero,
# Nearest to stage: latter, collection, against, eventually, president, national, out, however,
# Nearest to shows: then, musculus, links, clans, until, darker, they, ultramagnetic,
# Nearest to existence: denard, better, what, boggy, point, magellan, electorates, muscular,
# Nearest to mainly: ssr, official, late, major, including, what, only, their,
# Nearest to channel: salman, flavonoids, marotta, nevers, oersted, articulated, ecce, embryology,
# Nearest to mathematics: themselves, harwich, doom, thessalonica, perse, maxfield, similar, copernican,
# Nearest to running: restorer, clockwise, tsunamis, chalker, application, variable, impatience, bayle,
# Nearest to operations: low, seaton, sdp, fgm, honest, hauling, commodity, visio,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 11.1373 0.1312 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 10.8222 0.1294 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 10.8581 0.1295 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 10.9156 0.1298 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 10.6714 0.1311 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 10.6522 0.1311 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 10.6356 0.1309 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 10.7278 0.1308 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 10.6219 0.1294 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 10.5307 0.1298 sec/batch
# Nearest to new: the, in, of, and, to, a, at, from,
# Nearest to from: the, of, in, a, and, to, as, is,
# Nearest to but: to, the, it, of, that, a, is, in,
# Nearest to war: the, world, united, of, s, in, to, had,
# Nearest to its: to, the, of, in, and, which, by, that,
# Nearest to on: the, in, and, a, to, of, it, from,
# Nearest to years: the, zero, five, of, and, two, four, a,
# Nearest to one: nine, eight, seven, six, five, two, four, three,
# Nearest to stage: eventually, collection, president, against, latter, national, the, united,
# Nearest to shows: links, over, taken, musculus, darker, surgical, either, were,
# Nearest to existence: what, be, better, point, denard, different, though, if,
# Nearest to mainly: late, more, large, the, only, who, early, major,
# Nearest to channel: salman, flavonoids, marotta, remained, nevers, jean, articulated, ecce,
# Nearest to mathematics: thessalonica, doom, reports, harwich, perse, position, maxfield, communitarian,
# Nearest to running: restorer, clockwise, tsunamis, application, though, authority, even, exponential,
# Nearest to operations: low, honest, there, seaton, much, fgm, reserves, hauling,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 10.8451 0.1312 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 10.1985 0.1307 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 10.5842 0.1298 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 10.5019 0.1299 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 10.0960 0.1303 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 10.2879 0.1303 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 10.2852 0.1296 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 10.3091 0.1294 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 10.2375 0.0251 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 10.0515 0.1300 sec/batch
# Nearest to new: of, in, were, the, from, at, s, and,
# Nearest to from: the, of, in, a, to, and, as, that,
# Nearest to but: the, of, many, as, in, to, is, for,
# Nearest to war: united, was, against, the, after, had, in, from,
# Nearest to its: of, in, and, a, the, has, that, as,
# Nearest to on: the, of, s, in, to, a, and, as,
# Nearest to years: zero, over, two, the, five, of, in, by,
# Nearest to one: nine, seven, eight, six, four, five, two, three,
# Nearest to stage: collection, eventually, was, second, of, did, united, president,
# Nearest to shows: included, either, itself, case, links, others, various, common,
# Nearest to existence: what, better, form, believe, are, about, whereas, whether,
# Nearest to mainly: large, result, there, its, their, throughout, after, country,
# Nearest to channel: salman, flavonoids, east, marotta, due, nevers, jean, ecce,
# Nearest to mathematics: be, reports, position, doom, afghanistan, addition, harwich, itself,
# Nearest to running: used, case, be, large, did, set, much, could,
# Nearest to operations: low, were, around, association, free, most, often, east,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 10.0460 0.1306 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 10.0865 0.1290 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 9.8897 0.1284 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 10.0489 0.1287 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 9.7678 0.1298 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 9.6688 0.1293 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 9.7427 0.1289 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 9.6741 0.1293 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 9.5828 0.1308 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 9.1630 0.1309 sec/batch
# Nearest to new: the, in, and, was, of, one, at, by,
# Nearest to from: of, the, and, in, a, it, with, to,
# Nearest to but: of, the, and, in, a, as, have, to,
# Nearest to war: united, of, and, were, was, the, in, by,
# Nearest to its: the, of, and, in, to, has, a, many,
# Nearest to on: the, of, in, to, and, a, but, for,
# Nearest to years: two, zero, in, one, five, had, of, by,
# Nearest to one: nine, five, seven, two, eight, six, four, three,
# Nearest to stage: eventually, collection, public, second, became, formed, in, united,
# Nearest to shows: itself, will, little, include, only, were, outside, in,
# Nearest to existence: better, form, been, among, what, believe, several, like,
# Nearest to mainly: by, in, the, of, to, its, from, and,
# Nearest to channel: four, largest, salman, zero, broken, ii, flavonoids, nevers,
# Nearest to mathematics: be, reports, such, used, always, this, made, themselves,
# Nearest to running: could, may, with, be, many, which, left, a,
# Nearest to operations: system, association, which, third, low, set, common, fact,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 9.3353 0.1327 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 9.3732 0.1320 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 9.5424 0.1310 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 9.5233 0.1313 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 9.1730 0.1311 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 9.3219 0.1310 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 9.3601 0.1312 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 9.3884 0.1305 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 8.9498 0.1300 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 9.1080 0.1305 sec/batch
# Nearest to new: was, and, in, the, first, on, of, one,
# Nearest to from: the, of, to, in, and, has, as, with,
# Nearest to but: the, and, in, of, this, to, that, not,
# Nearest to war: were, ii, became, was, united, against, after, world,
# Nearest to its: the, of, to, in, a, that, and, it,
# Nearest to on: to, and, of, in, the, for, at, some,
# Nearest to years: zero, five, two, one, nine, united, six, four,
# Nearest to one: nine, five, eight, seven, three, two, four, zero,
# Nearest to stage: eventually, more, with, time, much, collection, were, the,
# Nearest to shows: an, sometimes, in, then, which, known, due, same,
# Nearest to existence: believe, as, some, such, is, have, generally, do,
# Nearest to mainly: the, and, although, from, to, a, in, during,
# Nearest to channel: four, one, popular, salman, century, broken, kingdom, continue,
# Nearest to mathematics: studies, public, themselves, detailed, people, seek, relatively, reports,
# Nearest to running: very, almost, off, often, with, by, as, these,
# Nearest to operations: a, than, often, and, by, generally, the, about,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 9.1294 0.1317 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 9.0482 0.1303 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 9.0210 0.1298 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 9.1866 0.1296 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 8.8322 0.1296 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 8.7741 0.1292 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 9.0033 0.1290 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 8.7431 0.1297 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 8.8296 0.1289 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 8.8054 0.1299 sec/batch
# Nearest to new: was, in, the, of, s, and, one, by,
# Nearest to from: a, and, of, to, the, as, in, with,
# Nearest to but: to, in, and, the, of, not, a, however,
# Nearest to war: after, united, led, during, in, had, was, were,
# Nearest to its: and, to, the, in, of, has, from, as,
# Nearest to on: of, a, the, to, in, and, s, at,
# Nearest to years: zero, two, was, five, four, one, after, three,
# Nearest to one: eight, six, two, seven, nine, five, three, four,
# Nearest to stage: at, in, eventually, a, more, well, because, several,
# Nearest to shows: than, it, at, is, of, and, time, to,
# Nearest to existence: how, we, there, least, consider, believe, been, as,
# Nearest to mainly: and, to, from, of, in, or, people, although,
# Nearest to channel: widely, moved, largest, three, zero, unknown, broken, kingdom,
# Nearest to mathematics: studies, take, detailed, include, therefore, we, already, cannot,
# Nearest to running: other, such, level, with, on, or, at, around,
# Nearest to operations: need, such, by, or, point, number, cannot, more,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 8.8808 0.1321 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 8.5352 0.1314 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 8.5680 0.1307 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 8.7316 0.1313 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 8.6794 0.1303 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 8.5948 0.1306 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 8.8938 0.1304 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 8.2853 0.1304 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 8.6131 0.1298 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 8.6966 0.1292 sec/batch
# Nearest to new: in, the, of, at, to, with, and, were,
# Nearest to from: the, in, of, with, and, to, a, was,
# Nearest to but: to, the, of, and, in, not, it, that,
# Nearest to war: civil, united, forces, was, during, states, government, were,
# Nearest to its: of, the, and, it, in, that, to, by,
# Nearest to on: the, in, and, at, of, by, a, s,
# Nearest to years: zero, at, the, two, world, population, during, first,
# Nearest to one: eight, nine, seven, six, five, two, four, three,
# Nearest to stage: started, on, received, a, the, at, an, after,
# Nearest to shows: which, will, to, an, about, like, while, though,
# Nearest to existence: generally, such, this, thought, others, believe, that, way,
# Nearest to mainly: the, and, people, europe, largest, also, in, between,
# Nearest to channel: widely, british, broken, and, list, mainly, large, currently,
# Nearest to mathematics: language, relatively, detailed, various, example, others, complete, therefore,
# Nearest to running: run, for, a, line, more, with, its, there,
# Nearest to operations: more, need, such, it, system, than, be, smaller,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 8.2877 0.1311 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 8.3457 0.1308 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 8.3857 0.1304 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 8.4662 0.1296 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 8.5163 0.1299 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 8.2025 0.1196 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 8.3037 0.1297 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 8.4320 0.1290 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 8.1512 0.1288 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 8.2935 0.1288 sec/batch
# Nearest to new: in, s, the, on, first, at, of, a,
# Nearest to from: the, of, and, in, as, to, a, on,
# Nearest to but: the, to, in, and, of, a, on, by,
# Nearest to war: united, forces, states, civil, army, military, government, was,
# Nearest to its: on, which, with, a, of, and, to, it,
# Nearest to on: a, in, the, to, with, of, for, and,
# Nearest to years: in, over, of, under, the, at, zero, by,
# Nearest to one: eight, nine, six, seven, two, five, four, three,
# Nearest to stage: on, a, had, in, at, to, first, third,
# Nearest to shows: is, a, that, usually, which, series, making, way,
# Nearest to existence: that, way, believe, nature, thought, there, if, what,
# Nearest to mainly: a, the, by, as, and, of, on, with,
# Nearest to channel: th, list, founded, zero, southwest, lowest, operations, small,
# Nearest to mathematics: characteristics, various, reality, detailed, physical, created, ideas, theory,
# Nearest to running: run, on, for, line, off, down, a, more,
# Nearest to operations: a, more, it, to, as, for, however, each,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 8.1134 0.1309 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 7.9222 0.1295 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 8.0282 0.1294 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 8.0470 0.1299 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 8.0674 0.1306 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 7.7036 0.1308 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 7.6872 0.1314 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 7.8337 0.1317 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 7.9510 0.1310 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 7.9540 0.1311 sec/batch
# Nearest to new: was, s, after, were, in, and, the, first,
# Nearest to from: and, the, of, in, a, to, by, for,
# Nearest to but: of, as, to, the, and, in, that, this,
# Nearest to war: army, was, civil, forces, were, states, after, led,
# Nearest to its: in, the, and, of, a, to, has, there,
# Nearest to on: the, to, of, and, a, in, for, it,
# Nearest to years: zero, two, three, five, one, six, four, over,
# Nearest to one: nine, three, seven, eight, four, two, six, zero,
# Nearest to stage: a, to, on, for, it, also, made, was,
# Nearest to shows: also, the, which, in, that, from, to, then,
# Nearest to existence: that, consider, only, nature, not, as, be, such,
# Nearest to mainly: the, in, and, from, of, has, as, by,
# Nearest to channel: southwest, special, interested, th, origin, october, founded, external,
# Nearest to mathematics: follows, reality, theory, simple, various, detailed, form, features,
# Nearest to running: for, to, a, often, it, line, system, or,
# Nearest to operations: to, use, number, provide, entire, a, limited, each,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 7.7163 0.1316 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 7.7889 0.1311 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 7.7730 0.1315 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 7.9013 0.1303 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 7.6559 0.1298 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 7.4815 0.1302 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 7.6917 0.1303 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 7.6562 0.1305 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 7.5360 0.1298 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 7.7773 0.1294 sec/batch
# Nearest to new: first, s, was, the, and, in, of, on,
# Nearest to from: the, of, as, also, and, in, to, by,
# Nearest to but: the, to, and, there, it, have, of, with,
# Nearest to war: army, led, civil, against, continued, forces, was, were,
# Nearest to its: the, in, has, a, for, of, to, also,
# Nearest to on: the, and, of, in, a, by, for, s,
# Nearest to years: over, zero, two, was, five, three, in, until,
# Nearest to one: nine, eight, six, seven, two, five, four, three,
# Nearest to stage: a, made, often, and, the, many, another, well,
# Nearest to shows: which, with, as, a, this, is, from, s,
# Nearest to existence: not, consider, particular, exist, true, there, that, sense,
# Nearest to mainly: of, has, the, although, from, there, and, areas,
# Nearest to channel: special, southwest, at, services, too, moved, links, maintained,
# Nearest to mathematics: analysis, theory, academic, follows, if, above, simple, studied,
# Nearest to running: on, a, the, more, for, have, at, made,
# Nearest to operations: a, provide, the, possible, for, are, an, more,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 7.4661 0.1305 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 7.3573 0.1298 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 7.6276 0.1290 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 7.4818 0.1291 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 7.4624 0.1298 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 7.4940 0.1292 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 7.5862 0.1303 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 7.1772 0.1310 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 7.3163 0.1310 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 7.2949 0.1315 sec/batch
# Nearest to new: the, of, s, and, was, in, by, with,
# Nearest to from: the, a, and, in, of, to, with, as,
# Nearest to but: a, in, this, that, to, of, the, and,
# Nearest to war: army, forces, peace, civil, during, government, against, led,
# Nearest to its: the, has, in, of, and, with, as, to,
# Nearest to on: the, of, in, to, and, by, a, has,
# Nearest to years: zero, population, two, s, five, over, seven, four,
# Nearest to one: seven, nine, eight, five, six, four, two, zero,
# Nearest to stage: with, made, and, get, but, they, home, a,
# Nearest to shows: called, which, show, same, time, than, most, to,
# Nearest to existence: our, true, we, is, any, reality, consider, nature,
# Nearest to mainly: since, mostly, from, small, its, and, of, parts,
# Nearest to channel: top, august, has, better, whose, market, included, opened,
# Nearest to mathematics: mathematical, theory, values, studied, space, follows, possible, analysis,
# Nearest to running: features, it, for, to, provide, performance, cost, the,
# Nearest to operations: it, limited, development, such, for, provide, an, and,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 7.4673 0.1318 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 7.3631 0.1300 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 7.5033 0.1301 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 7.3774 0.1303 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 7.1738 0.1303 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 7.4949 0.1295 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 7.2209 0.1304 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 7.1004 0.1309 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 7.1349 0.1306 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 7.3348 0.1299 sec/batch
# Nearest to new: in, was, had, by, first, of, the, after,
# Nearest to from: the, of, and, in, by, on, to, a,
# Nearest to but: the, to, have, that, and, for, on, in,
# Nearest to war: forces, civil, troops, states, united, former, army, against,
# Nearest to its: the, of, and, in, also, with, has, other,
# Nearest to on: the, s, and, a, in, of, for, from,
# Nearest to years: zero, birth, over, population, female, deaths, two, live,
# Nearest to one: nine, eight, seven, four, six, five, three, two,
# Nearest to stage: ever, play, show, with, appearance, up, and, first,
# Nearest to shows: show, a, many, on, is, for, as, an,
# Nearest to existence: idea, that, any, what, concept, sense, particular, not,
# Nearest to mainly: large, part, also, the, its, of, area, parts,
# Nearest to channel: performance, exception, new, market, which, programs, where, carried,
# Nearest to mathematics: mathematical, theory, analysis, values, set, is, numbers, fundamental,
# Nearest to running: run, for, on, with, performance, a, available, released,
# Nearest to operations: provide, operation, use, development, for, these, to, the,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 7.2715 0.1309 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 7.1439 0.0845 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 7.1006 0.1296 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 7.2168 0.1290 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 7.0385 0.1287 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 7.0821 0.1288 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 7.0696 0.1296 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 6.9415 0.1296 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 6.9009 0.1293 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 6.9472 0.1296 sec/batch
# Nearest to new: in, and, the, s, was, on, at, also,
# Nearest to from: the, in, and, of, a, to, for, on,
# Nearest to but: to, the, and, of, a, in, for, this,
# Nearest to war: united, army, civil, troops, forces, union, during, states,
# Nearest to its: for, and, to, the, in, of, from, is,
# Nearest to on: a, and, the, in, for, to, of, at,
# Nearest to years: two, zero, in, five, of, age, after, one,
# Nearest to one: seven, nine, eight, six, two, four, five, three,
# Nearest to stage: earlier, a, to, at, show, first, for, performance,
# Nearest to shows: a, it, the, as, is, with, also, and,
# Nearest to existence: belief, sense, nature, that, reality, our, understood, reason,
# Nearest to mainly: large, most, and, part, of, its, from, parts,
# Nearest to channel: computer, external, market, zero, shows, features, sold, competing,
# Nearest to mathematics: mathematical, theory, numbers, values, definition, fundamental, science, scientific,
# Nearest to running: a, for, run, on, an, to, off, line,
# Nearest to operations: operation, an, these, is, for, each, a, number,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 7.0008 0.1316 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 6.7435 0.1312 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 6.6656 0.1312 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 6.7272 0.1319 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 6.8682 0.1319 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 6.9726 0.1315 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 6.8237 0.1311 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 6.7118 0.1316 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 6.6524 0.1309 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 6.9226 0.1304 sec/batch
# Nearest to new: was, york, in, s, had, after, first, history,
# Nearest to from: the, and, in, a, of, by, as, to,
# Nearest to but: to, have, the, and, a, by, some, that,
# Nearest to war: army, civil, troops, forces, military, armed, against, france,
# Nearest to its: to, the, for, is, with, of, in, there,
# Nearest to on: the, in, of, to, a, and, for, with,
# Nearest to years: population, age, zero, s, at, people, over, after,
# Nearest to one: five, eight, six, seven, nine, four, three, two,
# Nearest to stage: also, an, in, best, first, on, the, a,
# Nearest to shows: also, same, s, the, with, a, and, in,
# Nearest to existence: not, that, does, understanding, sense, understood, particular, view,
# Nearest to mainly: part, and, most, into, mostly, western, many, areas,
# Nearest to channel: competing, television, special, station, made, operates, external, sold,
# Nearest to mathematics: mathematical, theory, analysis, complex, numbers, science, set, fundamental,
# Nearest to running: run, line, more, long, designed, on, performance, the,
# Nearest to operations: operation, a, the, on, these, program, number, for,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 6.8704 0.1311 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 6.5056 0.1300 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 6.6396 0.1301 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 6.7303 0.1303 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 6.6142 0.1301 sec/batch
# ...
# Nearest to mathematics: mathematical, theory, logic, abstract, theorem, analysis, mathematicians, science,
# Nearest to running: run, on, play, game, runs, line, performance, top,
# Nearest to operations: operation, ordered, operational, command, personnel, set, closed, operate,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 5.1372 0.1315 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 5.1189 0.1313 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 5.1631 0.1314 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 5.2426 0.1319 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 5.3412 0.1313 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 5.2093 0.1308 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 5.2340 0.1312 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 5.2214 0.1312 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 5.3685 0.1304 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 5.2709 0.1302 sec/batch
# Nearest to new: york, first, the, in, and, on, at, hall,
# Nearest to from: the, of, and, a, in, to, by, on,
# Nearest to but: it, to, that, and, the, they, only, of,
# Nearest to war: forces, army, troops, armed, allied, battle, military, failed,
# Nearest to its: the, this, and, a, of, to, on, into,
# Nearest to on: the, a, and, to, for, at, time, first,
# Nearest to years: age, population, male, zero, birth, female, five, four,
# Nearest to one: nine, seven, eight, five, four, six, zero, three,
# Nearest to stage: film, s, also, band, adaptation, studio, favorite, walk,
# Nearest to shows: also, s, picture, shown, with, like, original, show,
# Nearest to existence: belief, theory, philosophy, argued, reasoning, argument, philosophical, view,
# Nearest to mainly: europe, large, spread, western, east, today, largely, vast,
# Nearest to channel: broadcast, station, broadcasting, tv, television, stations, radio, broadcasts,
# Nearest to mathematics: mathematical, theory, logic, analysis, foundations, correspondence, theorem, mathematicians,
# Nearest to running: run, performance, game, track, runs, games, ran, released,
# Nearest to operations: operation, operational, provide, implemented, operate, implement, program, tasks,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 5.1005 0.1319 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 5.1873 0.1305 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 5.3046 0.1306 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 5.1310 0.1300 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 5.2849 0.1300 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 5.1490 0.1300 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 5.0429 0.1298 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 5.2049 0.1292 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 5.2208 0.1294 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 5.1512 0.1297 sec/batch
# Nearest to new: york, in, was, the, first, s, on, of,
# Nearest to from: in, the, of, and, as, with, a, known,
# Nearest to but: that, be, not, even, have, may, the, it,
# Nearest to war: army, forces, troops, allied, armed, led, battle, defeat,
# Nearest to its: has, the, of, and, however, which, with, in,
# Nearest to on: of, the, s, in, and, a, with, to,
# Nearest to years: birth, five, age, population, zero, two, one, female,
# Nearest to one: eight, five, six, nine, two, four, seven, three,
# Nearest to stage: song, favorite, theatre, audience, solo, songs, scenes, performed,
# Nearest to shows: show, featured, theme, picture, tv, series, credits, appearance,
# Nearest to existence: reality, that, nature, belief, theories, concept, explain, argued,
# Nearest to mainly: europe, today, part, east, main, and, mostly, region,
# Nearest to channel: broadcast, broadcasting, station, tv, stations, radio, television, network,
# Nearest to mathematics: mathematical, theory, logic, analysis, foundations, proof, studied, mathematicians,
# Nearest to running: run, runs, next, track, performance, screen, game, games,
# Nearest to operations: operation, operational, personnel, operate, command, aircraft, u, its,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 5.1616 0.1309 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 5.2445 0.1314 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 5.0013 0.1315 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 5.1083 0.1310 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 5.0955 0.1313 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 5.1975 0.1304 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 5.2055 0.1303 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 5.3318 0.1297 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 5.1958 0.1300 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 5.0874 0.1301 sec/batch
# Nearest to new: first, on, at, s, york, the, one, a,
# Nearest to from: the, of, in, and, while, a, also, as,
# Nearest to but: to, the, that, would, them, they, all, even,
# Nearest to war: forces, army, troops, were, led, military, allies, civil,
# Nearest to its: the, of, and, in, by, between, to, this,
# Nearest to on: the, s, a, first, at, was, by, in,
# Nearest to years: birth, zero, age, population, two, male, four, five,
# Nearest to one: eight, nine, six, seven, five, four, three, two,
# Nearest to stage: play, career, debut, theatre, performances, featured, favorite, band,
# Nearest to shows: like, picture, a, theme, show, examples, here, series,
# Nearest to existence: reality, belief, nature, knowledge, explain, idea, notions, thought,
# Nearest to mainly: mostly, asia, western, europe, region, primarily, areas, vast,
# Nearest to channel: network, broadcast, stations, networks, broadcasting, link, communications, channels,
# Nearest to mathematics: mathematical, theory, mathematicians, science, sciences, foundations, physics, logic,
# Nearest to running: run, runs, line, track, ran, game, performance, games,
# Nearest to operations: operation, command, operational, fixed, personnel, unit, u, extended,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 5.1635 0.1309 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 5.1071 0.1293 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 5.0306 0.1305 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 5.0501 0.1300 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 5.1069 0.1295 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 5.1368 0.1298 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 5.0980 0.0742 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 5.0500 0.1299 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 5.1413 0.1294 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 5.0956 0.1288 sec/batch
# Nearest to new: on, york, united, early, also, for, in, a,
# Nearest to from: the, of, in, and, as, a, which, by,
# Nearest to but: to, because, they, that, be, could, not, have,
# Nearest to war: forces, army, troops, civil, surrender, armed, battle, allies,
# Nearest to its: which, also, in, has, from, parts, into, within,
# Nearest to on: a, the, in, to, for, and, by, of,
# Nearest to years: birth, over, five, age, population, zero, three, year,
# Nearest to one: seven, eight, four, six, nine, five, two, three,
# Nearest to stage: record, play, pilot, show, neil, performance, crew, band,
# Nearest to shows: picture, theme, classic, like, show, credits, tv, featured,
# Nearest to existence: belief, exist, nature, question, rational, explain, knowledge, our,
# Nearest to mainly: parts, as, western, most, today, many, europe, especially,
# Nearest to channel: network, broadcast, broadcasting, stations, communications, radio, networks, station,
# Nearest to mathematics: mathematical, theory, mathematicians, abstract, theorem, cambridge, analysis, science,
# Nearest to running: run, runs, line, operating, performance, game, games, pass,
# Nearest to operations: operation, addition, operational, implemented, command, task, personnel, each,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 5.0451 0.1305 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 5.1201 0.1291 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 5.0049 0.1293 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.9340 0.1291 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.9785 0.1300 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 5.1016 0.1301 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.9536 0.1309 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.7996 0.1311 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.9172 0.1320 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.9319 0.1323 sec/batch
# Nearest to new: york, at, the, was, s, in, world, on,
# Nearest to from: the, and, of, in, other, a, its, there,
# Nearest to but: it, the, while, that, to, a, in, which,
# Nearest to war: army, forces, troops, fought, allied, fighting, invasion, against,
# Nearest to its: and, the, in, of, has, main, to, for,
# Nearest to on: the, at, to, by, in, a, and, for,
# Nearest to years: birth, age, male, population, five, six, over, deaths,
# Nearest to one: eight, six, three, five, two, seven, nine, four,
# Nearest to stage: successful, hours, adaptation, crew, back, produced, plays, off,
# Nearest to shows: like, picture, classic, trivia, scenes, show, tv, television,
# Nearest to existence: thought, arguments, knowledge, argument, idea, belief, accepted, principle,
# Nearest to mainly: and, europe, most, other, its, of, western, into,
# Nearest to channel: television, broadcasting, tv, broadcast, news, stations, pbs, bbc,
# Nearest to mathematics: mathematical, theory, mathematicians, science, numbers, theorem, analysis, abstract,
# Nearest to running: run, line, top, runs, next, game, huge, screen,
# Nearest to operations: operation, operational, command, task, u, personnel, ordered, armed,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 5.0373 0.1323 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.9958 0.1312 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.9194 0.1311 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.9356 0.1316 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 5.0344 0.1303 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 5.0775 0.1300 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.8633 0.1300 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.8507 0.1305 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.9980 0.1308 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.9063 0.1303 sec/batch
# Nearest to new: york, in, on, the, s, and, several, major,
# Nearest to from: the, and, of, in, with, to, also, as,
# Nearest to but: that, to, being, their, it, the, as, were,
# Nearest to war: army, troops, armed, allied, forces, military, allies, independence,
# Nearest to its: the, has, to, since, between, is, states, in,
# Nearest to on: the, and, of, to, a, in, for, with,
# Nearest to years: five, six, age, zero, year, three, four, over,
# Nearest to one: eight, seven, two, five, six, three, nine, four,
# Nearest to stage: performances, movie, producers, featured, plays, played, film, adaptation,
# Nearest to shows: picture, scenes, with, night, showing, looks, comedy, as,
# Nearest to existence: argument, nature, notion, theory, reality, exist, particular, our,
# Nearest to mainly: europe, region, principally, western, peoples, asia, parts, inhabitants,
# Nearest to channel: television, broadcasting, tv, broadcast, stations, station, bbc, radio,
# Nearest to mathematics: mathematical, theory, mathematicians, analysis, field, complex, theorem, science,
# Nearest to running: run, runs, ran, games, track, game, top, play,
# Nearest to operations: operation, operational, addition, system, provide, operate, personnel, group,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.9680 0.1310 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.9818 0.1298 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.7704 0.1296 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.9436 0.1298 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 5.0274 0.1292 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.8552 0.1294 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.9175 0.1295 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.9351 0.1301 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.8413 0.1315 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.7676 0.1313 sec/batch
# Nearest to new: major, now, also, in, the, on, including, of,
# Nearest to from: and, the, of, in, most, a, with, to,
# Nearest to but: to, not, be, the, this, however, as, it,
# Nearest to war: army, troops, armed, forces, allied, military, peace, conflict,
# Nearest to its: the, and, to, of, with, on, by, in,
# Nearest to on: the, of, and, has, to, in, its, with,
# Nearest to years: population, zero, female, one, male, over, birth, age,
# Nearest to one: five, two, three, four, six, seven, nine, zero,
# Nearest to stage: theatre, plays, performances, scenes, adaptation, artists, scene, broadway,
# Nearest to shows: show, picture, while, television, theme, series, star, short,
# Nearest to existence: argument, our, knowledge, thought, that, notion, true, understood,
# Nearest to mainly: and, parts, most, mostly, extensive, areas, world, diverse,
# Nearest to channel: channels, television, broadcast, networks, communications, network, link, stations,
# Nearest to mathematics: mathematical, mathematicians, mathematician, theory, studied, sciences, theorem, foundations,
# Nearest to running: run, top, track, drive, next, designed, hardware, operating,
# Nearest to operations: operation, personnel, u, operational, command, aircraft, support, operate,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.8455 0.1325 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.8934 0.1306 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.9302 0.1301 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.9929 0.1300 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 5.1224 0.1303 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.7853 0.1299 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.9326 0.1301 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.8975 0.1298 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.7421 0.1303 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.8494 0.1312 sec/batch
# Nearest to new: york, for, world, including, first, in, and, home,
# Nearest to from: the, in, of, as, and, to, most, with,
# Nearest to but: to, the, have, of, these, only, a, not,
# Nearest to war: forces, troops, civil, army, allied, invasion, attack, battle,
# Nearest to its: the, and, of, has, in, these, as, to,
# Nearest to on: the, at, and, for, a, of, in, s,
# Nearest to years: female, male, zero, population, birth, deaths, age, total,
# Nearest to one: nine, eight, seven, six, four, five, two, three,
# Nearest to stage: performances, plays, band, performer, scenes, film, debut, show,
# Nearest to shows: show, picture, shown, showing, on, also, movies, a,
# Nearest to existence: that, idea, knowledge, nature, argument, our, absolute, thought,
# Nearest to mainly: parts, asia, primarily, mostly, most, other, traditional, largest,
# Nearest to channel: communications, stations, broadcast, channels, station, network, broadcasting, link,
# Nearest to mathematics: mathematical, theory, mathematicians, theorem, science, sciences, applied, geometry,
# Nearest to running: run, runs, games, hardware, operating, platforms, compete, game,
# Nearest to operations: operation, operational, implement, joint, command, assigned, security, addition,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.8650 0.1312 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.9013 0.1298 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
